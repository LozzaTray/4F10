# %%
"""
In order to run the code as is, you will need scipy, pandas and tqdm installed 
(although tqdm is only needed for the progress bar, and pandas is only for the autocorrelation function)
All of these can be installed (on linux) from the command interface using 'pip'
""" 

import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
from gibbsrank import gibbs_sample
from eprank import eprank
import pandas
from cw2 import sorted_barplot

# %% [markdown]
# We first need to load the data, stored in "tennis_data.mat". The data consists of an array, $W$ containing the names of each player, and an array, G, containing the results of all of the matches in the season.

# %%
# set seed for reproducibility
np.random.seed(0)
# load data
data = sio.loadmat('tennis_data.mat')
# Array containing the names of each player
W = data['W']
# loop over array to format more nicely
for i, player in enumerate(W):
    W[i] = player[0]
# Array of size num_games x 2. The first entry in each row is the winner of game i, the second is the loser
G = data['G'] - 1
# Number of players
M = W.shape[0]
# Number of Games
N = G.shape[0]

# %%
player = "Novak-Djokovic"
print(np.where(W == player)[0])
# Out:
# [15]

# %% [markdown]
# # Gibbs sampling (This may take a minute)

# %%
# number of iterations
num_iters = 1100
# perform gibbs sampling, skill samples is an num_players x num_samples array
skill_samples = gibbs_sample(G, M, num_iters)#, random_nums)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1100/1100 [01:12<00:00, 15.11it/s]

# %%
sorted_barplot(skill_samples[:,-1], W)

# %%
# Code for plotting the autocorrelation function for player p
p = 0
n=20

print(W[p])
autocor = np.zeros(n)
for i in range(n):
    autocor[i]=pandas.Series.autocorr(pandas.Series(skill_samples[p,:]),lag=i)
plt.plot(autocor)
# Out:
# ['Rafael-Nadal']

# %%
p_arr = [15, 0, 27, 33]
for p in p_arr:
    name = W[p]
    print(name)
    plt.plot(skill_samples[p,:])
plt.legend(W[p_arr])
# Out:
# ['Novak-Djokovic']
# ['Rafael-Nadal']
# ['Michael-Llodra']
# ['Tomas-Berdych']

# %% [markdown]
# # EP ranking

# %%
num_iters = 3
# run message passing algorithm, returns mean and precision for each player
mean_player_skills, precision_player_skills = eprank(G, M, num_iters)

# %%
sorted_barplot(mean_player_skills, W)

# %%
sorted_barplot(precision_player_skills, W)

# %%
def sorted_rangeplot(mean, std_dev, W):
    M = len(mean)
    xx = np.linspace(0, M, M)
    plt.figure(figsize=(20, 20))
    sorted_indices = np.argsort(mean)
    sorted_names = W[sorted_indices]
    plt.barh(xx, width=std_dev[sorted_indices], left=mean[sorted_indices])
    plt.yticks(np.linspace(0, M, M), labels=sorted_names[:, 0])
    plt.ylim([-2, 109])
    plt.show()
    

std_dev = np.array([1 / precision for precision in precision_player_skills])
sorted_rangeplot(mean_player_skills, std_dev, W)
# Out:
# [-0.93989076 -0.92315759 -0.84761891 -0.79595971 -0.74183746 -0.70261479
#  -0.69953907 -0.68987454 -0.68608726 -0.68512623 -0.67494643 -0.65879615
#  -0.65663767 -0.62594515 -0.60019129 -0.60006425 -0.59590826 -0.57374209
#  -0.55234398 -0.53586611 -0.52382773 -0.50607848 -0.50410748 -0.49989313
#  -0.49394546 -0.49212885 -0.48172948 -0.47255784 -0.46789181 -0.44136032
#  -0.41783038 -0.40616138 -0.40267704 -0.39644963 -0.39286814 -0.3852818
#  -0.38206051 -0.3762139  -0.36924222 -0.36321928 -0.35112796 -0.34655588
#  -0.34625769 -0.34398999 -0.33921768 -0.33763317 -0.31830164 -0.30689219
#  -0.30236939 -0.27271785 -0.26563496 -0.26369156 -0.24112312 -0.23512476
#  -0.22444435 -0.19643702 -0.19192756 -0.16749485 -0.16437512 -0.1435878
#  -0.13387791 -0.13137724 -0.12440316 -0.12226057 -0.10784338 -0.09646446
#  -0.09645607 -0.09599356 -0.07618449 -0.06506793 -0.05524582 -0.00267659
#   0.00590406  0.02182955  0.05448307  0.05936418  0.06618584  0.0800537
#   0.09000091  0.09656346  0.1031488   0.15016003  0.15317969  0.16157448
#   0.21724888  0.24123712  0.26486871  0.27307674  0.28510203  0.29653204
#   0.29964898  0.30710939  0.3204802   0.34277196  0.34927819  0.37427312
#   0.37890438  0.44220246  0.55406666  0.58676573  0.62666351  0.80772869
#   0.82748994  1.05153434  1.20659154  1.25987534  1.61983366]
